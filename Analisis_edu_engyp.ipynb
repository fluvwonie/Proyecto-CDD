# %% [markdown]
# # **Analisis de los datos**

# %%
import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

# %%
import pandas as pd 
df=pd.read_csv('https://raw.githubusercontent.com/fluvwonie/World-/refs/heads/main/base_de_datos_limpia.csv')
df
# Out:
#            Student Name  Student Age Student year Father Degree  \
# 0         Jaclyn Mcneil           14       Year 9      Bachelor
# 1           Eric Steele           17      Year 11           PhD
# 2         Carrie Harvey           17       Year 9           PhD
# 3        Jon Williamson           17      Year 12   High School
# 4         Ashley Rogers           17      Year 12   High School
# ...                 ...          ...          ...           ...
# 20843       Karen Adams           15      Year 12   High School
# 20844      Ashley Jones           15      Year 12   High School
# 20845  Jeanette Hampton           14       Year 9           PhD
# 20846    Madeline Craig           17      Year 10        Master
# 20847   Joshua Castillo           16      Year 12           PhD
#
#       Education Type  Subject_1   Subject_2  Subject_3   Subject_4  \
# 0                 IB  91.603078   73.186427  64.240239   47.786542
# ...

# %% [markdown]
# Mostrar los datos estadisticos

# %%
df.describe().T
# Out:
#                count       mean        std        min        25%        50%  \
# Student Age  20848.0  16.012279   1.419104  14.000000  15.000000  16.000000
# Subject_1    20848.0  74.810691  14.313873  23.115667  65.009898  75.203132
# Subject_2    20848.0  74.675569  14.366906  20.000000  64.693881  74.963166
# Subject_3    20848.0  74.750117  14.360173  20.349550  64.961283  75.146877
# Subject_4    20848.0  74.641910  14.357677  20.000000  64.777327  74.853444
# Subject_5    20848.0  74.551177  14.332123  20.000000  64.748061  74.798934
# Subject_6    20848.0  74.606782  14.478923  20.000000  64.572515  74.912569
# Subject_7    20848.0  74.642770  14.322241  20.000000  64.857336  75.058072
# Subject_8    20848.0  74.710475  14.346535  20.000000  64.912285  74.907386
# Subject_9    20848.0  74.642344  14.334672  22.138571  64.915281  74.972165
# Subject_10   20848.0  74.588469  14.406369  20.000000  64.725069  74.892297
#
#                    75%    max
# ...

# %%
df.head(10)
# Out:
#      Student Name  Student Age Student year Father Degree Education Type  \
# 0   Jaclyn Mcneil           14       Year 9      Bachelor             IB
# 1     Eric Steele           17      Year 11           PhD          IGCSE
# 2   Carrie Harvey           17       Year 9           PhD          IGCSE
# 3  Jon Williamson           17      Year 12   High School             IB
# 4   Ashley Rogers           17      Year 12   High School          IGCSE
# 5     Joseph Long           14      Year 10           PhD             IB
# 6  Victor Hampton           17       Year 9        Master             IB
# 7   Amy Schneider           18       Year 9           PhD             IB
# 8  Timothy Miller           18       Year 9      Bachelor             IB
# 9   Carol Jenkins           18      Year 11   High School       Thanweya
#
#    Subject_1   Subject_2   Subject_3   Subject_4   Subject_5   Subject_6  \
# 0  91.603078   73.186427   64.240239   47.786542   83.138581   66.913702
# ...

# %%
#Comprobar valores unicos en cada columna 
for column in df.columns:
    print(column, df[column].nunique())
# Out:
# Student Name 18214
# Student Age 5
# Student year 4
# Father Degree 4
# Education Type 3
# Subject_1 19862
# Subject_2 19885
# Subject_3 19838
# Subject_4 19860
# Subject_5 19853
# Subject_6 19826
# Subject_7 19890
# Subject_8 19853
# Subject_9 19897
# Subject_10 19828
# Average_Grade 20848

# %%
#Calcular el promedio de las calificaciones

# Definir las columnas relacionadas con las materias
subject_columns = ['Subject_1', 'Subject_2', 'Subject_3', 'Subject_4', 'Subject_5',
                   'Subject_6', 'Subject_7', 'Subject_8', 'Subject_9', 'Subject_10']

# Calcular el promedio de todas las materias para cada estudiante
df['Average_Grade'] = df[subject_columns].mean(axis=1)

# Agrupar por 'Father Degree' y calcular el promedio de calificaciones
average_grades_by_father_degree = df.groupby('Father Degree')['Average_Grade'].mean()

# Mostrar los resultados
print(average_grades_by_father_degree)
# Out:
# Father Degree
# Bachelor       74.656101
# High School    74.651305
# Master         74.640392
# PhD            74.693331
# Name: Average_Grade, dtype: float64

# %%
#Filtrado del nombre 
df[df['Student Name']=='Michael Davis']
# Out:
#         Student Name  Student Age Student year Father Degree Education Type  \
# 6963   Michael Davis           15       Year 9           PhD          IGCSE
# 9236   Michael Davis           14      Year 10   High School             IB
# 9294   Michael Davis           14      Year 11        Master          IGCSE
# 9762   Michael Davis           18      Year 12   High School       Thanweya
# 10220  Michael Davis           18       Year 9        Master          IGCSE
# 11107  Michael Davis           17      Year 11      Bachelor       Thanweya
# 11779  Michael Davis           14       Year 9        Master             IB
# 17669  Michael Davis           17      Year 11      Bachelor       Thanweya
# 18104  Michael Davis           14      Year 10   High School          IGCSE
# 18863  Michael Davis           15       Year 9      Bachelor       Thanweya
# 19243  Michael Davis           18      Year 10      Bachelor             IB
#
# ...

# %%
nombres_similares = df['Student Name'].value_counts()[:30]

nombres_similares
# Out:
# Student Name
# Michael Davis        11
# Christopher Smith    10
# Michael Smith        10
# James Smith           8
# William Johnson       8
# James Jones           8
# Matthew Miller        8
# Michael Johnson       7
# Nicholas Davis        7
# David Johnson         7
# Michael Brown         7
# Anthony Smith         7
# James Johnson         7
# Michael Jones         7
# Lisa Williams         6
# David Williams        6
# Jennifer Clark        6
# Robert Williams       6
# Samantha Smith        6
# William Smith         6
# John Williams         6
# Robert Garcia         6
# Jennifer Williams     6
# Robert Wilson         6
# Jennifer Smith        6
# Aaron Smith           5
# Jason Miller          5
# Robert Martinez       5
# Robert Clark          5
# Anthony Miller        5
# Name: count, dtype: int64

# %%
nombres_frecuentes = df['Student Name'].value_counts().nlargest(20)


colors = plt.cm.RdBu(np.linspace(0, 1, len(nombres_frecuentes)))


nombres_frecuentes.plot(kind='barh', color=colors)


plt.title('Top 20 nombres más Frecuentes', fontsize=16)
plt.xlabel('Numero de frecuencia', fontsize=12)
plt.ylabel('Nombre del estudiante', fontsize=12)

plt.grid(True, which='both', axis='x', linestyle='--', linewidth=0.7, alpha=0.7)


plt.gca().invert_yaxis()


plt.show()

# %% [markdown]
#  Analisis de la edad del estudiante y del tipo de educacion

# %%
df['Student Age'].value_counts()
# Out:
# Student Age
# 18    4268
# 17    4168
# 15    4150
# 14    4149
# 16    4113
# Name: count, dtype: int64

# %%
student_counts = df['Student Age'].value_counts()

# Gráfico de pastel
color = sns.color_palette('BrBG')

plt.figure(figsize=(6,6))
plt.pie(student_counts, labels=student_counts.index, autopct='%1.1f%%', startangle=90, colors=color)
plt.title('Distribución por Nombre del Estudiante')
plt.show()

# %%
edu_counts = df['Education Type'].value_counts()

# Gráfico de pastel
color = sns.color_palette('PiYG')

plt.figure(figsize=(6,6))
plt.pie(edu_counts, labels=edu_counts.index, autopct='%1.1f%%', startangle=90, colors=color)
plt.title('Distribución del Tipo de Educacion')
plt.show()

# %%
df['Student Age'].groupby(df['Education Type']).value_counts()
# Out:
# Education Type  Student Age
# IB              18             1465
#                 15             1463
#                 17             1419
#                 14             1385
#                 16             1352
# IGCSE           18             1422
#                 16             1388
#                 14             1382
#                 17             1373
#                 15             1370
# Thanweya        14             1382
#                 18             1381
#                 17             1376
#                 16             1373
#                 15             1317
# Name: count, dtype: int64

# %%
sns.histplot(data=df, x='Student Age',hue ='Education Type', multiple="stack",palette="PuBu",kde=True, bins=30)

# Mostrar el gráfico
plt.title('Distribución del numero de estudiantes en cada Edad segun el tipo de educacion')
plt.xlabel('Edad del estudiante')
plt.ylabel('Numero de estudiantes')
plt.show()

# %% [markdown]
# Analisis del grado del padre

# %%
df['Father Degree'].value_counts()
# Out:
# Father Degree
# Bachelor       5221
# PhD            5160
# High School    4981
# Master         4946
# Name: count, dtype: int64

# %%
df['Father Degree'].groupby(df['Education Type']).value_counts()
# Out:
# Education Type  Father Degree
# IB              Bachelor         1762
#                 PhD              1749
#                 High School      1691
#                 Master           1681
# IGCSE           PhD              1766
#                 Bachelor         1689
#                 High School      1686
#                 Master           1635
# Thanweya        Bachelor         1770
#                 PhD              1645
#                 Master           1630
#                 High School      1604
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15, 6))

color = sns.color_palette('PiYG')

df['Father Degree'].value_counts().nlargest().plot(kind='bar', color=color)

# Personalización del gráfico
plt.title('Titulacion del Padre', fontsize=16)
plt.xlabel('Grado', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)

# Rotar las etiquetas del eje X
plt.xticks(rotation=45, ha='right')

# Añadir rejilla
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Analisis de las notas

# %%
#Calculamos la media aritmetica de los subject en relacion con las otras columnas 
df[['Subject_1','Subject_2','Subject_3','Subject_4','Subject_5',
      'Subject_6','Subject_7','Subject_8','Subject_9','Subject_10']].groupby(df['Student Age']).mean()
# Out:
#              Subject_1  Subject_2  Subject_3  Subject_4  Subject_5  Subject_6  \
# Student Age
# 14           74.493784  74.851820  74.537487  74.681918  74.884124  74.783601
# 15           74.631563  74.713539  74.804485  74.619519  74.898197  74.433482
# 16           74.993764  74.408468  74.868541  74.274138  74.351128  74.755203
# 17           74.776957  74.467506  74.817660  74.828607  74.447431  74.512632
# 18           75.149458  74.927900  74.723871  74.796884  74.184184  74.552316
#
#              Subject_7  Subject_8  Subject_9  Subject_10
# Student Age
# 14           74.651548  74.674427  74.411788   74.667066
# 15           74.626489  74.780726  74.541414   74.302572
# 16           74.712016  74.819406  74.779088   74.629330
# 17           74.757473  74.719174  74.657201   74.816119
# 18           74.471320  74.563739  74.818324   74.528364

# %%
df[['Subject_1','Subject_2','Subject_3','Subject_4','Subject_5','Subject_6','Subject_7',
      'Subject_8','Subject_9','Subject_10']].groupby(df['Education Type']).mean()
# Out:
#                 Subject_1  Subject_2  Subject_3  Subject_4  Subject_5  \
# Education Type
# IB              74.948562  74.486677  74.657852  74.445896  74.581052
# IGCSE           74.599856  74.812279  74.655707  74.854704  74.611066
# Thanweya        74.881780  74.732683  74.941704  74.629147  74.459367
#
#                 Subject_6  Subject_7  Subject_8  Subject_9  Subject_10
# Education Type
# IB              74.599309  74.500502  74.572163  74.554942   74.537455
# IGCSE           74.515238  74.646482  74.642873  74.750787   74.607488
# Thanweya        74.707499  74.786581  74.922603  74.622883   74.622074

# %%
df[['Subject_1','Subject_2','Subject_3','Subject_4','Subject_5','Subject_6',
      'Subject_7','Subject_8','Subject_9','Subject_10']].groupby(df['Father Degree']).mean()
# Out:
#                Subject_1  Subject_2  Subject_3  Subject_4  Subject_5  \
# Father Degree
# Bachelor       74.903958  74.574100  74.768129  74.710740  74.216090
# High School    74.446821  74.483792  74.747233  74.663475  74.888706
# Master         74.991576  74.829853  74.836120  74.442313  74.590777
# PhD            74.860269  74.812272  74.612726  74.826713  74.488546
#
#                Subject_6  Subject_7  Subject_8  Subject_9  Subject_10
# Father Degree
# Bachelor       74.501609  74.681606  74.823176  74.669835   74.711770
# High School    74.899667  74.415868  74.655217  74.521568   74.790704
# Master         74.434830  74.999734  74.437547  74.647804   74.193369
# PhD            74.626893  74.471782  74.872019  74.701075   74.661017

# %% [markdown]
# La media de todas es la misma, dependiendo la edad, el grado del padre y el tipo de educacion

# %% [markdown]
# Mostraremos a los top 10 estudiantes con mejores notas

# %%
df['Total'] = df['Subject_1']+df['Subject_2']+df['Subject_3']+df['Subject_4']+\
df['Subject_5']+df['Subject_6']+df['Subject_7']+df['Subject_8']+df['Subject_9']+df['Subject_10']

df['Total']
# Out:
# 0        725.122809
# 1        700.272092
# 2        709.062813
# 3        800.480152
# 4        764.920527
#             ...
# 20843    784.820928
# 20844    714.569320
# 20845    743.190848
# 20846    691.093427
# 20847    834.411344
# Name: Total, Length: 20848, dtype: float64

# %%
Top_10_students = df['Total'].nlargest(10)
Top_10_students
# Out:
# 2081     915.482753
# 1769     904.766691
# 14372    901.539626
# 15813    900.292684
# 19326    893.937366
# 12525    890.322950
# 11955    887.220796
# 11040    886.164296
# 15903    885.016860
# 3443     884.901567
# Name: Total, dtype: float64

# %%
df['Student Name'][Top_10_students.index]
# Out:
# 2081         Keith Moore
# 1769       Daniel Gordon
# 14372        Lauren Pugh
# 15813       Jeremy Blake
# 19326     Donald Hubbard
# 12525    Matthew Shields
# 11955    Thomas Randolph
# 11040       Derrick Yang
# 15903       Joseph Green
# 3443       Kelli Johnson
# Name: Student Name, dtype: object

# %%
sns.barplot(x=Top_10_students.values, y=df['Student Name'][Top_10_students.index] ,
            palette='viridis')




plt.title('Top 10 estudiantes con el maximo puntaje', fontsize=16)
plt.xlabel('Numero de frecuencia', fontsize=12)
plt.ylabel('Nombre de los alumnos', fontsize=12)

plt.grid(True, which='both', axis='x', linestyle='--', linewidth=0.7, alpha=0.7)





plt.show()
# Out:
# C:\Users\fatis\AppData\Local\Temp\ipykernel_30484\3154232.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=Top_10_students.values, y=df['Student Name'][Top_10_students.index] ,
